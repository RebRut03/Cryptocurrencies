# %%
# Dependencies to pull API
import requests
import json
# Google developer API key
from config import gkey

# %%
# Import Dependencies for Database
from config import password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import psycopg2
import pandas as pd

# %%
# db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5432/WineEnthusiast"

# %%
# engine = create_engine(db_string)
# inspector = inspect(engine)
# inspector.get_table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~\anaconda3\envs\mlenv\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "WineEnthusiast" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-cb66ee6deffc> in <module>
#       1 engine = create_engine(db_string)
# ----> 2 inspector = inspect(engine)
#       3 inspector.get_table_names()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3143             if connection is None:
#    3144                 Connection._handle_dbapi_exception_noconnection(
# -> 3145                     e, dialect, self
#    3146                 )
#    3147             else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2002         elif should_wrap:
#    2003             util.raise_(
# -> 2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#    2006         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "WineEnthusiast" does not exist
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# connection = engine.connect
# session = Session(engine)
# engine.execute("SELECT * from wine")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~\anaconda3\envs\mlenv\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "WineEnthusiast" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-35e0b0fc3f46> in <module>
#       1 connection = engine.connect
#       2 session = Session(engine)
# ----> 3 engine.execute("SELECT * from wine")
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3034
#    3035         """
# -> 3036         connection = self.connect(close_with_result=True)
#    3037         return connection.execute(statement, *multiparams, **params)
#    3038
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3143             if connection is None:
#    3144                 Connection._handle_dbapi_exception_noconnection(
# -> 3145                     e, dialect, self
#    3146                 )
#    3147             else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2002         elif should_wrap:
#    2003             util.raise_(
# -> 2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#    2006         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "WineEnthusiast" does not exist
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# col_names_list = []

# for i in range(len(inspector.get_columns('wine'))):
#     col_names_list.append(inspector.get_columns('wine')[i]['name'])
    
# print(col_names_list)
# Out:
# ['index', 'description', 'points', 'price', 'province', 'region_1', 'region_2', 'title', 'variety', 'winery']

# %%
# col_names = inspector.get_columns('wine')[5]['name']
# col_names
# Out:
# 'region_1'

# %%
# location_wine_df = pd.DataFrame(columns = col_names_list)

# %%
# # Inner join for wines and regions
# import sys
# join_db = engine.execute("SELECT region_1 from wine")
# for record in join_db:
#     record_series = pd.Series((record), index = location_wine_df.columns)
    
#     location_wine_df = location_wine_df.append(record_series, ignore_index=True, verify_integrity = True).drop_duplicates()

# %%
location_wine_df = pd.read_csv("US_wine_data.csv")

# %%
location_wine_df.columns
# Out:
# Index(['description', 'points', 'price', 'province', 'region_1', 'region_2',
#        'title', 'variety', 'winery', 'price_bins'],
#       dtype='object')

# %%
region_df = location_wine_df.drop(columns = ['description', 'points', 'price', 'province',
       'region_2', 'title', 'variety', 'winery','price_bins'], axis = 1)
region_df = region_df.drop_duplicates()

# %%
# Target valley
region = "Lodi"

# Build the endpoint URL
valley_url = ('https://maps.googleapis.com/maps/api/place/findplacefromtext/json?'
    'input={0}&key={1}&inputtype=textquery').format(region, gkey)

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(valley_url).json()

# Print the json
print(geo_data)
# Out:
# {'candidates': [{'place_id': 'ChIJNTjFJtmhmoARRuhsu5jkrY4'}], 'status': 'OK'}

# %%
place_id = geo_data['candidates'][0]['place_id']
place_id
# Out:
# 'ChIJNTjFJtmhmoARRuhsu5jkrY4'

# %%
place_url = ('https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJNTjFJtmhmoARRuhsu5jkrY4&key='+ gkey)

# %%
place_data = requests.get(place_url).json()
print(place_data)
# Out:
# {'html_attributions': [], 'result': {'address_components': [{'long_name': 'Lodi', 'short_name': 'Lodi', 'types': ['locality', 'political']}, {'long_name': 'San Joaquin County', 'short_name': 'San Joaquin County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'California', 'short_name': 'CA', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'adr_address': '<span class="locality">Lodi</span>, <span class="region">CA</span>, <span class="country-name">USA</span>', 'formatted_address': 'Lodi, CA, USA', 'geometry': {'location': {'lat': 38.1341477, 'lng': -121.2722194}, 'viewport': {'northeast': {'lat': 38.15494201474051, 'lng': -121.2413109180588}, 'southwest': {'lat': 38.08245401935762, 'lng': -121.4052700246796}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_pinlet', 'name': 'Lodi', 'photos': [{'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112239407976906936692">Amaranthine Witch</a>'], 'photo_reference': 'Aap_uEBbp4KRYiCDS1wHoXK_kP-oxfh8fsk9Dcu88TrGqYxRCehyhXP_xos-nRgskTOkuXVly3ca6aMpd4NimMziN7WKzxcs3XUwJrRDXhev19HXocSXkvGPuA7Z5VZipamdsAcum44cEZbwl6CsrO9alZCty4UbZQ9RlwQayOqdsZSR56Bz', 'width': 3024}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111007459724078383770">Raghu Sharma</a>'], 'photo_reference': 'Aap_uEAv9vrAZAOBDN7iFPIdFw4IpWm-VRutjbOZ0TamDoKeL0goXKFtbezrj-9BtSANFoMR1h2Y5CIyMJeEgzWy-jc_OHoHjPnipqXS75Wup6_KyWCQLiZjrcqcMSMP54t7nRpnJLo3Hih3iLMuKCAO47yhbty0nyZjB5uV_4f1CGkoI_Ot', 'width': 4032}, {'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101580070492939978025">Elizabeth B.</a>'], 'photo_reference': 'Aap_uECYZMbIcw_pp4p0InLs6JQXGErzDxvETRpa78XpeUdawPNULxi6puvTSGBHIUyetFH-n-TYxo7oKc0Q7l5EEtsXmWvF2eGZKea_r_y57P76tAvrL6WRP-lSneSCJYfVTcIBQczt_jGEUFq3rxUvGkjcz6fHGC4gAcgKbTj6MB1Hi6gc', 'width': 3024}, {'height': 3472, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113223740402964500583">Danielle Allman</a>'], 'photo_reference': 'Aap_uEBCOrY9g6rAAzqT497Kwet71r1Unz91f6dA3d_z34_vg1dmaw4AavNlcCLJ5ROLzadFdLBwZjnmaRnmGotGde5JmprTOpnR4BFHl4b6VUSGR5RktJ2CGDwhGdb6eVYnjujNFstJVGYm5IOAB1_gMhCb9vWIqg9L03-NYcGs7nXFRBcw', 'width': 4624}, {'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113042563689030833631">Marie Miglietta</a>'], 'photo_reference': 'Aap_uEC8sy-RyeE_8AOQWEhtwjjybH1iDZQCRCZrDjX3fx5kpNt75TQWPNRqlJK5mBdN8HvJEDq629lXrKWe707TCSpL1quJZbikYPT45dHCTYyV7yHdGAjjYFT6aXvrEhF811Sp0EBg9lsH38NSQDLRxFPf8NxZNlL_2uWNtkzcjsyguv6h', 'width': 3024}, {'height': 4008, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103145431707773308843">Caitlin Bindner</a>'], 'photo_reference': 'Aap_uEA9s7m8NsUVYIdBw4aT8qVj32uTGqbj-zbLB2-MmNnyYN712x2ru02W5T0mM5_VR_Lat9P2X7d3jIOxJIW_vBuky2BQLfiMznwJQae7b9iNsI4xWb9DxCB4XL3t1HBKDErdS9V0trCZ6jG8NySwhvVw0ZoR9R3E7E2OgLti2LtWDxzQ', 'width': 5344}, {'height': 5344, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103145431707773308843">Caitlin Bindner</a>'], 'photo_reference': 'Aap_uEAmQiQvf65PqXxtDv6MvBQGDGgG7jicQhNkdtfRSH8eApktprnyw44qBPQnLNmJvJi6FG25h7-EmrdBLL70eeHkVluB5DdA5G-yCzTyjIS66Ga_XO90SVRkZxT2xIeDwB1qckm3d45fVjOwkMsaW0cC0oi0QmoUhdB8NLD401A66hDt', 'width': 4008}, {'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107369998101403950975">jose lourenco</a>'], 'photo_reference': 'Aap_uEBChtvZKwSKvNENUm3VJY9qhVKcUBs8OxpEoO2y9N52gQ74lcmeQwhPVatBel4GQGVzmbb-iehFUPLRwgEQPcKmnqd9URDc08-2LfPoihx6hiJq_F2lGqhuVRGQ1blJp7KRea3_ssGJLiUH9ZEZot7LSvzXzu8bf0QAMzNFgCkiyLkP', 'width': 4032}, {'height': 3264, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108481542724957208903" ...

# %%
latitude = place_data['result']['geometry']['location']['lat']
latitude
# Out:
# 38.1341477

# %%
longitude = place_data['result']['geometry']['location']['lng']
longitude
# Out:
# -121.2722194
